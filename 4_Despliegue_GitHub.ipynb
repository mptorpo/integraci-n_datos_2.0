# %% [markdown]
# <a href="https://colab.research.google.com/github/mptorpo/integraci-n_datos_2.0/blob/main/4_Despliegue_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Depligue de Datos**
#
# En esta seccion se hara el despligue de datos en paginas web utilizanodo la plataforma GitHub. La Plataforma GitHub es una plataforma para el desarrollo y despliegue de datos conjunta con diferentes grupos de trabajo.

# %% [markdown]
# 0. Se cargan las librerias de trabajo

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')

import IPython.display as display
import base64 #Convierto en Imagen
import request
